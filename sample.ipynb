# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('cleaned_data.csv')

# Display the first few rows of the dataset to understand its structure
print(data.head())
print(data.info())
# Out:
#          SuggestedJobRole                                   keywords  \
# 0       Technical Support                       ms, ma, ba, business
# 1      Software Developer     ma, business, ms, bachelor, ba, degree
# 2  Applications Developer               ma, ms, bachelor, ba, degree
# 3      Software Developer  ma, ms, bachelor, ba, degree, engineering
# 4      Software Developer                                     ms, ba
#
#    Logical quotient rating  hackathons  coding skills rating  \
# 0                        7           2                     9
# 1                        5           3                     1
# 2                        1           6                     9
# 3                        3           0                     6
# 4                        2           3                     9
#
#    public speaking points self-learning capability? Extra-courses did  \
# 0                       9                        no               yes
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.naive_bayes import CategoricalNB
from sklearn.metrics import accuracy_score, classification_report

# Load the dataset
data = pd.read_csv('cleaned_data.csv')

# Selecting features and target
features = ['Logical quotient rating', 'hackathons', 'coding skills rating', 'public speaking points',
            'self-learning capability?', 'Extra-courses did', 'certifications', 'workshops', 
            'memory capability score', 'Interested subjects', 'interested career area ', 
            'Type of company want to settle in?', 'hard/smart worker', 'worked in teams ever?', 'Introvert']
target = 'SuggestedJobRole'

# Encoding categorical variables
encoder = OrdinalEncoder()
data_encoded = data.copy()
data_encoded[features] = encoder.fit_transform(data[features])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data_encoded[features], data_encoded[target], test_size=0.3, random_state=42)

# Initialize the CategoricalNB model
model = CategoricalNB()

# Train the model
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.26033333333333336
#                                            precision    recall  f1-score   support
#
#                    Applications Developer       0.22      0.20      0.21       456
#                   CRM Technical Developer       0.26      0.24      0.25       539
#                        Database Developer       0.12      0.01      0.02       209
#             Mobile Applications Developer       0.00      0.00      0.00        24
#                 Network Security Engineer       0.00      0.00      0.00        39
#                        Software Developer       0.27      0.50      0.35       674
#                         Software Engineer       0.28      0.37      0.32       596
# Software Quality Assurance (QA) / Testing       0.00      0.00      0.00        17
#            Systems Security Administrator       0.00      0.00      0.00        28
#                         Technical Support       0.00      0.00      0.00       152
# ...
